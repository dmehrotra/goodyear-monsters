# %%
from sas7bdat import SAS7BDAT
import numpy as np
import pandas as pd
from numpy.random import randn
from pandas import Series, DataFrame, Index
from IPython.display import Image
df.drop(['B', 'C'], axis=1)
accident_data = SAS7BDAT('data/2012/fars/accident.sas7bdat')
vehicle_data = SAS7BDAT('data/2012/fars/vehicle.sas7bdat')
# Out:
# [Format11.sas] magic number mismatch
# [Format11.sas] [Format11.sas] magic number mismatch
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e28a626b4354> in <module>()
#      10 vehicle_data = SAS7BDAT('FSAS2011/vehicle.sas7bdat')
#      11 factor_data = SAS7BDAT('FSAS2011/factor.sas7bdat')
# ---> 12 format_data = SAS7BDAT('FSAS2011/Format11.sas')
#
# /Users/Mehrotra/Library/Python/2.7/lib/python/site-packages/sas7bdat.pyc in __init__(self, path, log_level, extra_time_format_strings, extra_date_time_format_strings, extra_date_format_strings, skip_header, encoding, encoding_errors, align_correction)
#     452         self.header = SASHeader(self)
#     453         self.properties = self.header.properties
# --> 454         self.header.parse_metadata()
#     455         self.logger.debug('\n%s', str(self.header))
#     456         self._iter = self.readlines()
#
# ...

# %%
accident = accident_data.to_data_frame()
cevent = cevent_data.to_data_frame()
vehicle = vehicle_data.to_data_frame()
factor = factor_data.to_data_frame()

# %%
list(factor)
# Out:
# [u'STATE', u'ST_CASE', u'VEH_NO', u'MFACTOR']

# %%
factor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44178 entries, 0 to 44177
# Data columns (total 4 columns):
# STATE      44178 non-null float64
# ST_CASE    44178 non-null float64
# VEH_NO     44178 non-null float64
# MFACTOR    44178 non-null float64
# dtypes: float64(4)
# memory usage: 1.3 MB

# %%
list(accident)
# Out:
# [u'STATE',
#  u'ST_CASE',
#  u'VE_TOTAL',
#  u'VE_FORMS',
#  u'PVH_INVL',
#  u'PEDS',
#  u'PERNOTMVIT',
#  u'PERMVIT',
#  u'PERSONS',
#  u'COUNTY',
#  u'CITY',
#  u'DAY',
#  u'MONTH',
#  u'YEAR',
#  u'DAY_WEEK',
#  u'HOUR',
#  u'MINUTE',
#  u'NHS',
#  u'ROAD_FNC',
#  u'ROUTE',
#  u'TWAY_ID',
#  u'TWAY_ID2',
#  u'MILEPT',
#  u'LATITUDE',
#  u'LONGITUD',
#  u'SP_JUR',
#  u'HARM_EV',
#  u'MAN_COLL',
#  u'RELJCT1',
#  u'RELJCT2',
#  u'TYP_INT',
#  u'REL_ROAD',
#  u'WRK_ZONE',
#  u'LGT_COND',
#  u'WEATHER1',
#  u'WEATHER2',
#  u'WEATHER',
#  u'SCH_BUS',
#  u'RAIL',
#  u'NOT_HOUR',
#  u'NOT_MIN',
#  u'ARR_HOUR',
#  u'ARR_MIN',
#  u'HOSP_HR',
#  u'HOSP_MN',
#  u'CF1',
#  u'CF2',
#  u'CF3',
#  u'FATALS',
#  u'DRUNK_DR']

# %%
cevent.tail(20)
# Out:
#        STATE   ST_CASE  EVENTNUM  VNUMBER1  AOI1   SOE  VNUMBER2  AOI2
# 90367   56.0  560116.0       1.0       1.0  12.0   8.0    9999.0  77.0
# 90368   56.0  560117.0       1.0       1.0  55.0  63.0    5555.0  55.0
# 90369   56.0  560117.0       2.0       1.0   0.0   1.0    9999.0  77.0
# 90370   56.0  560118.0       1.0       1.0  55.0  68.0    5555.0  55.0
# 90371   56.0  560118.0       2.0       1.0  55.0  64.0    5555.0  55.0
# 90372   56.0  560118.0       3.0       1.0   0.0   1.0    9999.0  77.0
# 90373   56.0  560119.0       1.0       1.0  12.0   8.0    9999.0  77.0
# 90374   56.0  560120.0       1.0       1.0  55.0  68.0    5555.0  55.0
# 90375   56.0  560120.0       2.0       2.0  55.0  68.0    5555.0  55.0
# 90376   56.0  560120.0       3.0       1.0  55.0  68.0    5555.0  55.0
# 90377   56.0  560120.0       4.0       1.0  12.0  12.0       2.0  12.0
# 90378   56.0  560120.0       5.0       2.0  55.0  64.0    5555.0  55.0
# ...
